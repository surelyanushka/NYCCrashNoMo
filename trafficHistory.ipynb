# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import dask.dataframe as dd
from shapely import wkt
import warnings
warnings.filterwarnings("ignore")
# Out:
# /opt/homebrew/anaconda3/envs/DaskEnv/lib/python3.12/site-packages/dask/dataframe/__init__.py:31: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
trafficData = dd.read_csv("data/DOT_Traffic_Speeds_NBE_20240430.csv", on_bad_lines = 'skip', blocksize = '16MB') # Data with ~12 million rows
zipcodeData = pd.read_csv('data/Modified_Zip_Code_Tabulation_Areas__MODZCTA_.csv')

# %%
import dask.config
dask.config.config['dataframe']['convert-string'] = False

def getCleanData(trafficDf):
    columns = [
        "ID",
        "LINK_ID",
        "ENCODED_POLY_LINE",
        "ENCODED_POLY_LINE_LVLS",
        "OWNER",
        "TRANSCOM_ID",
        "LINK_NAME"
    ]

    trafficDf = trafficDf.drop(columns = columns)
    return trafficDf

def getExplodedDataLink(trafficDf):
    '''
        Link points column in orignal data is a Space separated string of latitude,longitudes
        This functions splits them into individual lat,long pairs and explodes it to later map each pair to a zipcode provided in the zipcode column.
    '''
    trafficDf["LINK_POINTS"] = trafficDf['LINK_POINTS'].apply(lambda x : x.split(' ')[:-1],meta = list)
    trafficDf = trafficDf.explode('LINK_POINTS')
    trafficDf['pointWKT'] = trafficDf['LINK_POINTS'].apply(lambda x: f'Point({x.split(",")[1]} {x.split(",")[0]})' if len(x.split(",")) == 2 else np.nan)
    trafficDf = trafficDf.dropna(subset=['pointWKT'])
    return trafficDf

def getExplodedDataTraffic(trafficDf):
    '''
        Same utility as above
    '''
    trafficDf["LINK_POINTS"] = trafficDf['LINK_POINTS'].apply(lambda x : x.split(' ')[:-1],meta = list)
    trafficDf = trafficDf.explode('LINK_POINTS')
    return trafficDf

def getZipcodeCol(trafficDf):
    '''
        After exploding the day scales up a lotttt
        Here link points are extracted into a seperated Dataframe and mapped to a zipcode
        Then this DF is joined with the traffic Data.
        This will save a lot of time as it works on unique lat long pairs only and doesnt have to go through all the rows of traffic data
    '''
    linkPointsCol = trafficDf[['LINK_POINTS']]
    linkPointsCol = linkPointsCol.drop_duplicates()
    linkPointsCol = getExplodedDataLink(linkPointsCol)
    linkPointsCol = linkPointsCol.drop_duplicates()
    def getZipcode(pointWKT):
        point = wkt.loads(pointWKT)
        for i in range(len(zipcodeData.index)):
            r = zipcodeData.iloc[i]
            polygon = wkt.loads(r.the_geom)
            if polygon.contains(point):
                return r.MODZCTA
        return np.NAN
    
    linkPointsCol['Zipcode'] = linkPointsCol['pointWKT'].apply(lambda x : getZipcode(x), meta = int)
    linkPointsCol = linkPointsCol.drop(columns = ['pointWKT'])
    linkPointsCol = linkPointsCol.dropna(subset = ['Zipcode'])
    return linkPointsCol
    
def mapTrafficZipcode(trafficDf, linkPointsCol):
    trafficDf = getExplodedDataTraffic(trafficDf)
    trafficDf = trafficDf.merge(linkPointsCol, on = 'LINK_POINTS')
    return trafficDf

def getSplitDate(trafficDf):
    trafficDf['dateTime'] = trafficDf['DATA_AS_OF'].apply(lambda x: datetime.strptime(x, '%m/%d/%Y %H:%M:%S %p'), meta = datetime)
    trafficDf['year'] = trafficDf['dateTime'].apply(lambda x: x.year, meta = int)
    trafficDf['month'] = trafficDf['dateTime'].apply(lambda x: x.month, meta = int)
    trafficDf['date'] = trafficDf['dateTime'].apply(lambda x: x.day, meta = int)
    trafficDf['hour'] = trafficDf['dateTime'].apply(lambda x: x.hour, meta = int)
    trafficDf = trafficDf.drop(columns = ['dateTime'])
    return trafficDf

def groupbyAvgHour(trafficDf):
    '''
        Grouping by to get average traffic speed of any given hour or any given lat long pair.
        This is where the problem is. 
        This code keeps on running for days
    '''
    trafficDf = trafficDf.groupby(['year', 'month', 'date', 'hour','LINK_POINTS','Zipcode','BOROUGH']).agg({'SPEED':'mean'})
    return trafficDf

# %%
cleanData = getCleanData(trafficData.copy())
PointZipcode = getZipcodeCol(cleanData)
finalTrafficDf = mapTrafficZipcode(cleanData, PointZipcode)
finalTrafficDf = getSplitDate(finalTrafficDf)

# %%
finalTrafficDf.to_csv("data/output/History-*.csv", index = False)
# Out:
# ['/Users/neelgandhi/Big Dat/Final Project/output/History-000.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-001.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-002.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-003.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-004.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-005.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-006.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-007.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-008.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-009.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-010.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-011.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-012.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-013.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-014.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-015.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-016.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-017.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-018.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-019.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-020.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-021.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-022.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-023.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-024.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-025.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-026.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-027.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-028.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-029.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-030.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-031.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-032.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-033.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-034.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-035.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-036.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-037.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-038.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-039.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-040.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-041.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-042.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-043.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-044.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-045.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-046.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-047.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-048.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-049.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-050.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-051.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-052.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-053.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-054.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-055.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-056.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-057.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-058.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-059.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-060.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-061.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-062.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-063.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-064.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-065.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-066.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-067.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-068.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-069.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-070.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-071.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-072.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-073.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-074.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-075.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-076.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-077.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-078.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-079.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-080.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-081.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-082.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-083.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-084.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-085.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-086.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-087.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-088.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-089.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-090.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-091.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-092.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-093.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-094.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-095.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-096.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-097.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-098.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-099.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-100.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-101.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-102.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-103.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-104.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-105.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-106.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-107.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-108.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-109.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-110.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-111.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-112.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-113.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-114.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-115.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-116.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-117.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-118.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-119.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-120.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-121.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-122.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-123.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-124.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-125.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-126.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-127.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-128.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-129.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-130.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-131.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-132.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-133.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-134.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-135.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-136.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-137.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-138.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-139.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-140.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-141.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-142.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-143.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-144.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-145.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-146.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-147.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-148.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-149.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-150.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-151.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-152.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-153.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-154.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-155.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-156.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-157.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-158.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-159.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-160.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-161.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-162.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-163.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-164.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-165.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-166.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-167.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-168.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-169.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-170.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-171.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-172.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-173.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-174.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-175.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-176.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-177.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-178.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-179.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-180.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-181.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-182.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-183.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-184.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-185.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-186.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-187.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-188.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-189.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-190.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-191.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-192.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-193.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-194.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-195.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-196.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-197.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-198.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-199.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-200.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-201.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-202.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-203.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-204.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-205.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-206.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-207.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-208.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-209.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-210.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-211.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-212.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-213.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-214.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-215.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-216.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-217.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-218.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-219.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-220.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-221.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-222.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-223.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-224.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-225.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-226.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-227.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-228.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-229.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-230.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-231.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-232.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-233.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-234.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-235.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-236.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-237.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-238.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-239.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-240.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-241.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-242.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-243.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-244.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-245.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-246.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-247.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-248.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-249.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-250.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-251.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-252.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-253.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-254.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-255.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-256.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-257.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-258.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-259.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-260.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-261.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-262.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-263.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-264.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-265.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-266.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-267.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-268.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-269.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-270.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-271.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-272.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-273.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-274.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-275.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-276.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-277.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-278.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-279.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-280.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-281.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-282.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-283.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-284.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-285.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-286.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-287.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-288.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-289.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-290.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-291.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-292.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-293.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-294.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-295.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-296.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-297.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-298.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-299.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-300.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-301.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-302.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-303.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-304.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-305.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-306.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-307.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-308.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-309.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-310.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-311.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-312.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-313.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-314.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-315.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-316.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-317.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-318.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-319.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-320.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-321.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-322.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-323.csv',
#  '/Users/neelgandhi/Big Dat/Final Project/output/History-324.csv']

# %%
finalTrafficDf = groupbyAvgHour(finalTrafficDf)

# %%
savedData = dd.read_csv("data/output/History-*.csv")
savedData = groupbyAvgHour(savedData)
savedData = savedData.reset_index()
savedData.head(20)
# Out:
#     year  month  date  hour            LINK_POINTS  Zipcode    BOROUGH  \
# 0   2023     12    31    11     40.80151,-73.93066  10035.0  Manhattan
# 1   2023     12    31    11      40.8014,-73.93111  10035.0  Manhattan
# 2   2023     12    31    11   40.8012304,-73.93129  10035.0  Manhattan
# 3   2023     12    31    11     40.80096,-73.93141  10035.0  Manhattan
# 4   2023     12    31    11   40.8007405,-73.93133  10035.0  Manhattan
# 5   2023     12    31    11    40.800501,-73.93106  10035.0  Manhattan
# 6   2023     12    31    11     40.80026,-73.93057  10035.0  Manhattan
# 7   2023     12    31    11        40.81,-73.93002  10451.0  Manhattan
# 8   2023     12    31    11   40.7997606,-73.92972  10035.0  Manhattan
# 9   2023     12    31    11  40.7994205,-73.929511  10035.0  Manhattan
# 10  2023     12    31    11     40.79901,-73.92945  10035.0  Manhattan
# 11  2023     12    31    11     40.78802,-73.79003  11360.0     Queens
# 12  2023     12    31    11   40.7868604,-73.78838  11360.0     Queens
# 13  2023     12    31    11  40.7863506,-73.787771  11360.0     Queens
# 14  2023     12    31    11  40.7854504,-73.786831  11360.0     Queens
# 15  2023     12    31    11    40.78502,-73.786481  11360.0     Queens
# 16  2023     12    31    11   40.7848004,-73.78632  11360.0     Queens
# 17  2023     12    31    11   40.7844005,-73.78601  11360.0     Queens
# 18  2023     12    31    11  40.7837704,-73.785671  11360.0     Queens
# 19  2023     12    31    11   40.7831705,-73.78538  11360.0     Queens
#
#         SPEED
# 0   26.417619
# 1   26.417619
# 2   26.417619
# 3   26.417619
# 4   26.417619
# 5   26.417619
# 6   26.417619
# 7   26.417619
# 8   26.417619
# 9   26.417619
# 10  26.417619
# 11  51.155238
# 12  51.155238
# 13  51.155238
# 14  51.155238
# 15  51.155238
# 16  51.155238
# 17  51.155238
# 18  51.155238
# 19  51.155238

# %%
savedData.to_csv("data/groupedOutput/*.csv", index = False)
# Out:
# ['/Users/neelgandhi/Big Dat/Final Project/groupedOutput/0.csv']
